# %% [markdown]
# Импортируем библиотеку

# %%
# %%time
from TSEnsemble import utils, nn, arima
# Out:
# CPU times: total: 3.98 s
# Wall time: 4.37 s

# %% [markdown]
# Преобразуем .csv файл в DataFrame, состоящий из 1 столбца со значениями <br> временного ряда (column) и индекса, содержащего даты (index).

# %%
# %%time
path = "TestScripts\\datasets\\GlobalTemperatures.csv"
dataset = utils.ts_from_csv(path, column = 1, index = 0)
# Out:
# CPU times: total: 0 ns
# Wall time: 14 ms

# %% [markdown]
# Декомпозируем временной ряд на составляющие: тренд, сезонность, остатки.

# %%
# %%time
utils.plot_decompose(path, period = 12)
# Out:
# CPU times: total: 1.12 s
# Wall time: 1.15 s

# %% [markdown]
# Строим функцию автокорелляции для временного ряда, по ней можно увидеть сезонность ряда.

# %%
# %%time
from statsmodels.graphics.tsaplots import plot_acf
utils.plot_acf(path, lags = 26)
# Out:
# CPU times: total: 62.5 ms
# Wall time: 38 ms

# %% [markdown]
# Проверим ряд на стационарность, используя 2 теста: KPSS и ADF. <br> Также нарисуем график временного ряда, средних значений и стандартных<br> отклонений прошлых window значений (по умолчанию 2% датасета)

# %%
# %%time
utils.isStationary(path, window = 24, plot = True)
# Out:
# ADF test:
#  stat        -4.036404
# pval         0.001231
# lags        28.000000
# numobs    3163.000000
# 1%          -3.432419
# 5%          -2.862454
# 10%         -2.567257
# dtype: float64
# KPSS test:  stat      1.409546
# pval      0.010000
# lags    149.000000
# 10%       0.347000
# 5%        0.463000
# 2.5%      0.574000
# 1%        0.739000
# dtype: float64
# CPU times: total: 359 ms
# Wall time: 202 ms
# C:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\TSEnsemble\utils.py:172: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   test_kpss = kpss(ts)
# False

# %% [markdown]
# Автоматически найдем наиболее оптимальные коэффициенты для SARIMA <br> модели по критерию AIC и построим модель.

# %%
# %%time
ar = arima.auto_arima(dataset,
                            method = 'stepwise',
                            season = 12,
                            max_p = 3,
                            max_q = 3,
                            max_Q = 3,
                            max_P = 3,
                            train_split = 0.95,
                            plot = True)
# Out:
# C:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\TSEnsemble\utils.py:250: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   test_kpss = kpss(ts)
# C:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\TSEnsemble\utils.py:250: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   test_kpss = kpss(ts)
# SARIMA[2, 1, 2] [1, 1, 1, 12] AIC:inf  Time_Taken:15.141
# SARIMA[0, 1, 0] [0, 1, 0, 12] AIC:10102.140  Time_Taken:0.125
# SARIMA[1, 1, 0] [1, 1, 0, 12] AIC:8882.128  Time_Taken:0.547
# SARIMA[0, 1, 1] [0, 1, 1, 12] AIC:inf  Time_Taken:1.953
# SARIMA[0, 1, 0] [1, 1, 0, 12] AIC:9272.559  Time_Taken:0.391
# SARIMA[1, 1, 0] [0, 1, 0, 12] AIC:9669.414  Time_Taken:0.125
# SARIMA[2, 1, 0] [1, 1, 0, 12] AIC:8767.364  Time_Taken:0.812
# SARIMA[1, 1, 0] [1, 1, 0, 12] AIC:8882.128  Time_Taken:0.531
# SARIMA[2, 1, 0] [0, 1, 0, 12] AIC:9564.930  Time_Taken:0.172
# SARIMA[3, 1, 0] [1, 1, 0, 12] AIC:8696.185  Time_Taken:0.891
# SARIMA[3, 1, 0] [0, 1, 0, 12] AIC:9506.098  Time_Taken:0.234
# SARIMA[3, 1, 1] [1, 1, 0, 12] AIC:inf  Time_Taken:9.500
# SARIMA[3, 1, 0] [2, 1, 0, 12] AIC:8451.195  Time_Taken:1.734
# SARIMA[2, 1, 0] [2, 1, 0, 12] AIC:8519.633  Time_Taken:1.797
# SARIMA[3, 1, 1] [2, 1, 0, 12] AIC:inf  Time_Taken:36.375
# SARIMA[3, 1, 0] [3, 1, 0, 12] AIC:8250.504  Time_Taken:3.734
# SARIMA[2, 1, 0] [3, 1, 0, 12] AIC:8322.141  Time_Taken:3.453
# SARIMA[3, 1, 1] [3, 1, 0, 12] AIC:inf  Time_Taken:77.922
# SARIMA[3, 1, 0] [3, 1, 1, 12] AIC:inf  Time_Taken:43.219
# SARIMA[3, 1, 0] [2, 1, 1, 12] AIC:inf  Time_Taken:26.906
# Best model: [3, 1, 0] [3, 1, 0, 12], AIC: 8250.504
# Total time:  225.90625
#      prediction  actual
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.3516623745329281, MSE = 0.1236664256621374, MAE = 0.26352182083441456, MAPE = 0.042117482796404405
# CPU times: total: 3min 46s
# Wall time: 2min 38s

# %% [markdown]
# Построим CNN, LSTM, GRU, Transformer модели, пытаясь подобрать оптимальные параметры.

# %%
# %%time
cnn = nn.make_cnn(dataset,
                  look_back = 12,
                  hidden_layers = 1,
                  train_size = 0.95,
                  kernel_size = 2,
                  filters = 12,
                    epochs = 50,
                  batch_size = 64,
                  dilation_rate = 1,
                  dilation_mode = "additive")
# Out:
# 5/5 [==============================] - 0s 1ms/step
#      prediction  actual
# 0     12.149379  12.911
# 1      9.877851  10.424
# 2      7.345591   6.727
# 3      4.730360   5.133
# 4      3.843074   3.525
# ..          ...     ...
# 143   14.137775  14.755
# 144   12.164734  12.999
# 145   10.154995  10.801
# 146    7.306258   7.433
# 147    5.191300   5.518
#
# [148 rows x 2 columns]
# RMSE = 0.5122272537482644, MSE = 0.2623767594824888, MAE = 0.43251515222937414, MAPE = 0.05418719611401738
# CPU times: total: 5.36 s
# Wall time: 4.45 s

# %%
# %%time
lstm = nn.make_rnn(dataset,
                  look_back = 12,
                  units = 64,
                  hidden_layers = 1,
                  train_size = 0.95,
                  type = "LSTM",
                  epochs = 20,
                  batch_size = 16,
                  dropout = 0.0,
                  maxPlot = 100)
# Out:
# 5/5 [==============================] - 0s 2ms/step
#      prediction  actual
# 0     12.650519  12.911
# 1     10.198710  10.424
# 2      7.422891   6.727
# 3      4.596901   5.133
# 4      3.450284   3.525
# ..          ...     ...
# 143   14.273006  14.755
# 144   12.704264  12.999
# 145   10.232183  10.801
# 146    7.571732   7.433
# 147    4.994514   5.518
#
# [148 rows x 2 columns]
# RMSE = 0.5605127354430736, MSE = 0.314174526593877, MAE = 0.47233773679296337, MAPE = 0.0603472502416931
# CPU times: total: 41.5 s
# Wall time: 18.7 s

# %%
# %%time
gru = nn.make_rnn(dataset,
                  look_back = 12,
                  hidden_layers = 1,
                  units = 64,
                  train_size = 0.95,
                  type = "GRU",
                  dropout = 0.0,
                  maxPlot = 100)
# Out:
# 5/5 [==============================] - 0s 2ms/step
#      prediction  actual
# 0     12.704336  12.911
# 1     10.110059  10.424
# 2      7.337024   6.727
# 3      4.661689   5.133
# 4      3.820265   3.525
# ..          ...     ...
# 143   14.354935  14.755
# 144   12.714123  12.999
# 145   10.134203  10.801
# 146    7.527487   7.433
# 147    5.110621   5.518
#
# [148 rows x 2 columns]
# RMSE = 0.4611823654350509, MSE = 0.21268917418826885, MAE = 0.3859517565772217, MAPE = 0.05051716571649687
# CPU times: total: 37.3 s
# Wall time: 17.7 s

# %%
# %%time
transformer = nn.make_transformer(dataset, 
                    look_back = 12, 
                    train_size = 0.95,
                    maxPlot = 100, 
                    batch_size = 32,
                    epochs = 30,
                    verbose = 0,
                    horizon = 1,
                    n_features = 1,
                    num_transformer_blocks = 4,
                    dropout = 0.25, 
                    head_size = 256, 
                    num_heads = 4, 
                    ff_dim = 4,
                    mlp_units=[128],
                    mlp_dropout=0.4)
# Out:
# 5/5 [==============================] - 0s 23ms/step
#      prediction  actual
# 0     12.413152  12.911
# 1      9.962452  10.424
# 2      6.814686   6.727
# 3      4.343928   5.133
# 4      3.816258   3.525
# ..          ...     ...
# 143   14.081531  14.755
# 144   12.539993  12.999
# 145    9.986661  10.801
# 146    6.940286   7.433
# 147    4.775481   5.518
#
# [148 rows x 2 columns]
# RMSE = 0.5147307275411422, MSE = 0.26494772187503357, MAE = 0.45230320951299197, MAPE = 0.05636755115215218
# CPU times: total: 13min 18s
# Wall time: 2min 59s

# %% [markdown]
# Построим acl модель, используя параметры для моделей, подобранные ранее.

# %%
# %%time
acl = nn.ACL()
acl = acl.fit(dataset,
              order = (3, 1, 0), 
              seasonal_order = (3, 1, 0, 12), 
              look_back = 12,
              train_size= 0.95, 
              filters = 64, 
              cnn_layers = 3, 
              dilation_mode = "multiplicative", 
              lstm_layers = 1,
              units = 64, 
              kernel_size = 2, 
              epochs = 20)
# Out:
# AIC:  8250.504306275288
# 5/5 [==============================] - 1s 19ms/step
#      prediction  actual
# 0     13.874816  12.911
# 1     12.025314  10.424
# 2      8.894189   6.727
# 3      6.013009   5.133
# 4      4.113795   3.525
# ..          ...     ...
# 143   15.985909  14.755
# 144   14.486409  12.999
# 145   12.440238  10.801
# 146    9.895510   7.433
# 147    6.895193   5.518
#
# [148 rows x 2 columns]
# RMSE = 1.2746288975268845, MSE = 1.6246788264106007, MAE = 1.0047900978290647, MAPE = 0.14024854152463198
# CPU times: total: 11min 54s
# Wall time: 3min 49s

# %% [markdown]
# Сгенерируем ненатреннированные модели с уже подобранными параметрами,<br> и создаздим ансамблевую модель, которая будет работать по принципу <br> взвешенного среднего, основываясь на оценке ошибки MAPE.

# %%
# %%time
from statsmodels.tsa.arima.model import ARIMA
ar = ARIMA(dataset, order = (3, 1, 0), seasonal_order = (3, 1, 0, 12))

transformer = nn.generate_transformer(
                    look_back = 12,
                    horizon = 1,
                    n_features = 1,
                    num_transformer_blocks = 4,
                    dropout = 0.25, 
                    head_size = 256, 
                    num_heads = 4, 
                    ff_dim = 4,
                    mlp_units=[128],
                    mlp_dropout=0.4)

lstm = nn.generate_rnn(look_back = 12,
                    hidden_layers = 1,
                    units = 64,
                    type = "LSTM",
                    dropout = 0.0)

cnn = nn.generate_cnn(look_back = 12,
                hidden_layers = 3,
                kernel_size = 2,
                filters = 64,
                dilation_rate = 1,
                dilation_mode = "multiplicative")
from TSEnsemble.ensemble import Ensemble
ensemble_model = Ensemble(models = [ar, cnn, lstm, transformer], regressor = 'lr')
ensemble_model.fit(dataset, 
                   train_size = 0.9505, 
                   look_back = 12, 
                   val_size = 0.2, 
                   train_models_size = 0.7, 
                   epochs = 20, 
                   batch_size = 16, 
                   metric = "rmse")
ensemble_model.eval(get="rmse")
# Out:
# C:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#      prediction       1
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.35166237453292815
#
# 23/23 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.4205054264369519
#
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3691593522851332
#
# 23/23 [==============================] - 1s 28ms/step
# 6/6 [==============================] - 0s 23ms/step
# 5/5 [==============================] - 0s 27ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.38928617038034735
#      prediction  actual
# 0     13.017785  12.950
# 1     10.569361   9.988
# 2      7.374818   6.892
# 3      4.912794   4.038
# 4      3.808032   3.981
# ..          ...     ...
# 155   14.873270  14.755
# 156   13.040067  12.999
# 157   10.646660  10.801
# 158    7.576456   7.433
# 159    5.274104   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.4301502726978271, MSE = 0.185029257102015, MAE = 0.34220597457602625, MAPE = 0.04963419617820903
# CPU times: total: 6min 10s
# Wall time: 2min 17s
# 0.4301502726978271

# %%
# %%time

ensemble_model = Ensemble(models = [ar, cnn, lstm, transformer],
                          regressor = 'catboost',
                          regr_params ={'iterations': 20,                         
                                        'task_type' : "GPU",
                                        'devices' : '0:1',
                                        'depth': 10,
                                       'verbose': 0}
                         )
ensemble_model.fit(dataset, fit_models = False, train_size = 0.9505, look_back = 12, val_size = 0.2, train_models_size = 0.8, epochs = 20, batch_size = 16, metric = "rmse")
ensemble_model.eval(get="rmse")
# Out:
#      prediction       1
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.35166237453292815
#
# 16/16 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.41960142989163957
#
# 16/16 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3685821608816821
#
# 16/16 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 27ms/step
# 5/5 [==============================] - 0s 26ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.3881990159826481
#      prediction  actual
# 0     11.755548  12.950
# 1      9.832934   9.988
# 2      7.326584   6.892
# 3      4.255303   4.038
# 4      3.702822   3.981
# ..          ...     ...
# 155   14.105974  14.755
# 156   11.826192  12.999
# 157    9.924080  10.801
# 158    7.326584   7.433
# 159    4.946242   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.5835544383054805, MSE = 0.3405357824660248, MAE = 0.4823163622127148, MAPE = 0.05719509307020423
# CPU times: total: 14.1 s
# Wall time: 11.4 s
# 0.5835544383054805

# %%
# %%time

ensemble_model = Ensemble(models = [ar, cnn, lstm, transformer], regressor = 'wmean')
ensemble_model.fit(dataset, fit_models = False, train_size = 0.9505, look_back = 12, val_size = 0.2, train_models_size = 0.8, epochs = 20, batch_size = 16, metric = "rmse")
ensemble_model.eval(get="rmse")
# Out:
#      prediction       1
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.35166237453292815
#
# 16/16 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.41960142989163957
#
# 16/16 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3685821608816821
#
# 16/16 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 5/5 [==============================] - 0s 43ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.3881990159826481
#      prediction  actual
# 0     12.981473  12.950
# 1     10.384792   9.988
# 2      7.359250   6.892
# 3      4.898694   4.038
# 4      3.864850   3.981
# ..          ...     ...
# 155   14.776774  14.755
# 156   12.973301  12.999
# 157   10.452137  10.801
# 158    7.574231   7.433
# 159    5.304367   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.3752405512754186, MSE = 0.14080547132148005, MAE = 0.28047363394347996, MAPE = 0.04654569080253148
# CPU times: total: 13.8 s
# Wall time: 10.8 s
# 0.3752405512754186

# %%
# %%time

ensemble_model = Ensemble(models = [ar, cnn, lstm, transformer], regressor = 'knn', regr_params = {'n_neighbors': 2})
ensemble_model.fit(dataset, fit_models = False, train_size = 0.9505, look_back = 12, val_size = 0.2, train_models_size = 0.8, epochs = 20, batch_size = 16, metric = "rmse")
ensemble_model.eval(get="rmse")
# Out:
#      prediction       1
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.35166237453292815
#
# 16/16 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.41960142989163957
#
# 16/16 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3685821608816821
#
# 16/16 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 24ms/step
# 5/5 [==============================] - 0s 28ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.3881990159826481
#      prediction  actual
# 0       12.0960  12.950
# 1        9.5795   9.988
# 2        5.9310   6.892
# 3        3.8170   4.038
# 4        3.3830   3.981
# ..          ...     ...
# 155     14.4705  14.755
# 156     12.0960  12.999
# 157      9.3515  10.801
# 158      5.9310   7.433
# 159      5.3395   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.6887616843382768, MSE = 0.47439265781250006, MAE = 0.574690625, MAPE = 0.07468542538669315
# CPU times: total: 13.3 s
# Wall time: 10.6 s
# 0.6887616843382768

# %%
# %%time

ensemble_model = Ensemble(models = [ar, cnn, lstm, transformer], regressor = 'svr', regr_params = {'C': 1.0,
                          'epsilon': 0.2})
ensemble_model.fit(dataset, fit_models = False, train_size = 0.9505, look_back = 12, val_size = 0.2, train_models_size = 0.8, epochs = 20, batch_size = 16, metric = "rmse")
ensemble_model.eval(get="rmse")
# Out:
#      prediction       1
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.35166237453292815
#
# 16/16 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.41960142989163957
#
# 16/16 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3685821608816821
#
# 16/16 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 5/5 [==============================] - 0s 28ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.3881990159826481
#      prediction  actual
# 0     12.898649  12.950
# 1     10.145740   9.988
# 2      7.047747   6.892
# 3      4.334116   4.038
# 4      3.509942   3.981
# ..          ...     ...
# 155   14.431584  14.755
# 156   12.879092  12.999
# 157   10.214965  10.801
# 158    7.277857   7.433
# 159    4.744131   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.3479646762838206, MSE = 0.12107941594130409, MAE = 0.2793599627936749, MAPE = 0.04039727175356781
# CPU times: total: 12.8 s
# Wall time: 10.5 s
# 0.3479646762838206

# %%
ensemble_model = Ensemble(models = [ar, cnn, lstm, transformer],
                          regressor = 'catboost',
                          regr_params ={'iterations': 200,                         
                                        'task_type' : "GPU",
                                        'devices' : '0:1',
                                        'depth': 10}
                         )
ensemble_model.fit(dataset, fit_models = False, train_size = 0.9505, look_back = 12, val_size = 0.2, train_models_size = 0.8, epochs = 20, batch_size = 16, metric = "rmse")
ensemble_model.eval(get="rmse")
# Out:
#      prediction       1
# 0     12.740215  12.950
# 1      9.892806   9.988
# 2      6.781601   6.892
# 3      4.465869   4.038
# 4      3.599770   3.981
# ..          ...     ...
# 155   14.909026  14.755
# 156   13.119663  12.999
# 157   10.259375  10.801
# 158    7.248030   7.433
# 159    4.795211   5.518
#
# [160 rows x 2 columns]
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.35166237453292815
#
# 16/16 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 1ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.41960142989163957
#
# 16/16 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3685821608816821
#
# 16/16 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 24ms/step
# 5/5 [==============================] - 0s 25ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.3881990159826481
#
# Learning rate set to 0.090861
# 0:	learn: 3.7906965	test: 3.8208870	best: 3.8208870 (0)	total: 7.43ms	remaining: 1.48s
# 1:	learn: 3.4759800	test: 3.6635412	best: 3.6635412 (1)	total: 14.1ms	remaining: 1.39s
# 2:	learn: 3.1856704	test: 3.3843356	best: 3.3843356 (2)	total: 20.7ms	remaining: 1.36s
# 3:	learn: 2.9173659	test: 3.1192391	best: 3.1192391 (3)	total: 27.6ms	remaining: 1.35s
# 4:	learn: 2.6696180	test: 2.8781215	best: 2.8781215 (4)	total: 34.1ms	remaining: 1.33s
# 5:	learn: 2.4437652	test: 2.6601077	best: 2.6601077 (5)	total: 40.3ms	remaining: 1.3s
# 6:	learn: 2.2426672	test: 2.4694052	best: 2.4694052 (6)	total: 46.4ms	remaining: 1.28s
# 7:	learn: 2.0580334	test: 2.2996457	best: 2.2996457 (7)	total: 52.6ms	remaining: 1.26s
# 8:	learn: 1.8889686	test: 2.1382449	best: 2.1382449 (8)	total: 58.9ms	remaining: 1.25s
# 9:	learn: 1.7318916	test: 1.9882088	best: 1.9882088 (9)	total: 65.1ms	remaining: 1.24s
# 10:	learn: 1.5900963	test: 1.8531332	best: 1.8531332 (10)	total: 71.3ms	remaining: 1.22s
# 11:	learn: 1.4620514	test: 1.7328778	best: 1.7328778 (11)	total: 77.3ms	remaining: 1.21s
# 12:	learn: 1.3437095	test: 1.6623244	best: 1.6623244 (12)	total: 83.5ms	remaining: 1.2s
# 13:	learn: 1.2365024	test: 1.5623026	best: 1.5623026 (13)	total: 90.1ms	remaining: 1.2s
# 14:	learn: 1.1366578	test: 1.4633543	best: 1.4633543 (14)	total: 96.3ms	remaining: 1.19s
# 15:	learn: 1.0485776	test: 1.3841429	best: 1.3841429 (15)	total: 103ms	remaining: 1.18s
# 16:	learn: 0.9681370	test: 1.3217511	best: 1.3217511 (16)	total: 109ms	remaining: 1.17s
# 17:	learn: 0.8960058	test: 1.2575944	best: 1.2575944 (17)	total: 115ms	remaining: 1.16s
# 18:	learn: 0.8286126	test: 1.1932696	best: 1.1932696 (18)	total: 121ms	remaining: 1.16s
# 19:	learn: 0.7671628	test: 1.1536211	best: 1.1536211 (19)	total: 128ms	remaining: 1.15s
# 20:	learn: 0.7126614	test: 1.1032918	best: 1.1032918 (20)	total: 134ms	remaining: 1.14s
# 21:	learn: 0.6630020	test: 1.0583299	best: 1.0583299 (21)	total: 140ms	remaining: 1.13s
# 22:	learn: 0.6176409	test: 1.0353264	best: 1.0353264 (22)	total: 147ms	remaining: 1.13s
# 23:	learn: 0.5780201	test: 0.9973776	best: 0.9973776 (23)	total: 153ms	remaining: 1.12s
# 24:	learn: 0.5410579	test: 0.9618485	best: 0.9618485 (24)	total: 159ms	remaining: 1.11s
# 25:	learn: 0.5083072	test: 0.9413153	best: 0.9413153 (25)	total: 165ms	remaining: 1.11s
# 26:	learn: 0.4785746	test: 0.9118761	best: 0.9118761 (26)	total: 171ms	remaining: 1.1s
# 27:	learn: 0.4524766	test: 0.8993852	best: 0.8993852 (27)	total: 178ms	remaining: 1.09s
# 28:	learn: 0.4295308	test: 0.8768105	best: 0.8768105 (28)	total: 185ms	remaining: 1.09s
# 29:	learn: 0.4091341	test: 0.8542998	best: 0.8542998 (29)	total: 192ms	remaining: 1.09s
# 30:	learn: 0.3905442	test: 0.8478052	best: 0.8478052 (30)	total: 200ms	remaining: 1.09s
# 31:	learn: 0.3748551	test: 0.8307848	best: 0.8307848 (31)	total: 208ms	remaining: 1.09s
# 32:	learn: 0.3609636	test: 0.8179093	best: 0.8179093 (32)	total: 215ms	remaining: 1.09s
# 33:	learn: 0.3485742	test: 0.8022344	best: 0.8022344 (33)	total: 222ms	remaining: 1.08s
# 34:	learn: 0.3375575	test: 0.7881585	best: 0.7881585 (34)	total: 229ms	remaining: 1.08s
# 35:	learn: 0.3277559	test: 0.7754104	best: 0.7754104 (35)	total: 235ms	remaining: 1.07s
# 36:	learn: 0.3190751	test: 0.7739249	best: 0.7739249 (36)	total: 242ms	remaining: 1.07s
# 37:	learn: 0.3109492	test: 0.7706891	best: 0.7706891 (37)	total: 249ms	remaining: 1.06s
# 38:	learn: 0.3048264	test: 0.7648780	best: 0.7648780 (38)	total: 255ms	remaining: 1.05s
# 39:	learn: 0.2990213	test: 0.7572408	best: 0.7572408 (39)	total: 262ms	remaining: 1.05s
# 40:	learn: 0.2938783	test: 0.7563291	best: 0.7563291 (40)	total: 269ms	remaining: 1.04s
# 41:	learn: 0.2893476	test: 0.7532798	best: 0.7532798 (41)	total: 276ms	remaining: 1.04s
# 42:	learn: 0.2853893	test: 0.7442104	best: 0.7442104 (42)	total: 282ms	remaining: 1.03s
# 43:	learn: 0.2818954	test: 0.7414763	best: 0.7414763 (43)	total: 289ms	remaining: 1.02s
# 44:	learn: 0.2790461	test: 0.7383428	best: 0.7383428 (44)	total: 295ms	remaining: 1.02s
# 45:	learn: 0.2760402	test: 0.7338328	best: 0.7338328 (45)	total: 302ms	remaining: 1.01s
# 46:	learn: 0.2734131	test: 0.7322354	best: 0.7322354 (46)	total: 308ms	remaining: 1s
# 47:	learn: 0.2713996	test: 0.7267670	best: 0.7267670 (47)	total: 314ms	remaining: 995ms
# 48:	learn: 0.2690747	test: 0.7216824	best: 0.7216824 (48)	total: 321ms	remaining: 989ms
# 49:	learn: 0.2673651	test: 0.7195845	best: 0.7195845 (49)	total: 327ms	remaining: 982ms
# 50:	learn: 0.2657677	test: 0.7171342	best: 0.7171342 (50)	total: 334ms	remaining: 976ms
# 51:	learn: 0.2636025	test: 0.7120930	best: 0.7120930 (51)	total: 341ms	remaining: 970ms
# 52:	learn: 0.2620091	test: 0.7122128	best: 0.7120930 (51)	total: 348ms	remaining: 964ms
# 53:	learn: 0.2603820	test: 0.7105158	best: 0.7105158 (53)	total: 355ms	remaining: 959ms
# 54:	learn: 0.2592587	test: 0.7090124	best: 0.7090124 (54)	total: 362ms	remaining: 954ms
# 55:	learn: 0.2581026	test: 0.7082240	best: 0.7082240 (55)	total: 368ms	remaining: 947ms
# 56:	learn: 0.2569639	test: 0.7077609	best: 0.7077609 (56)	total: 375ms	remaining: 942ms
# 57:	learn: 0.2558565	test: 0.7062072	best: 0.7062072 (57)	total: 383ms	remaining: 937ms
# 58:	learn: 0.2547941	test: 0.7058339	best: 0.7058339 (58)	total: 392ms	remaining: 937ms
# 59:	learn: 0.2534035	test: 0.7053843	best: 0.7053843 (59)	total: 403ms	remaining: 941ms
# 60:	learn: 0.2526109	test: 0.7038726	best: 0.7038726 (60)	total: 415ms	remaining: 946ms
# 61:	learn: 0.2518304	test: 0.7025410	best: 0.7025410 (61)	total: 426ms	remaining: 948ms
# 62:	learn: 0.2512666	test: 0.7014982	best: 0.7014982 (62)	total: 432ms	remaining: 941ms
# 63:	learn: 0.2504267	test: 0.7012476	best: 0.7012476 (63)	total: 440ms	remaining: 934ms
# 64:	learn: 0.2495902	test: 0.6996110	best: 0.6996110 (64)	total: 447ms	remaining: 929ms
# 65:	learn: 0.2489472	test: 0.6993549	best: 0.6993549 (65)	total: 454ms	remaining: 923ms
# 66:	learn: 0.2481218	test: 0.6975111	best: 0.6975111 (66)	total: 461ms	remaining: 914ms
# 67:	learn: 0.2472522	test: 0.6976165	best: 0.6975111 (66)	total: 467ms	remaining: 906ms
# 68:	learn: 0.2462938	test: 0.6973105	best: 0.6973105 (68)	total: 473ms	remaining: 898ms
# 69:	learn: 0.2457829	test: 0.6972472	best: 0.6972472 (69)	total: 479ms	remaining: 890ms
# 70:	learn: 0.2451517	test: 0.6960902	best: 0.6960902 (70)	total: 486ms	remaining: 883ms
# 71:	learn: 0.2447101	test: 0.6947966	best: 0.6947966 (71)	total: 493ms	remaining: 877ms
# 72:	learn: 0.2437794	test: 0.6946577	best: 0.6946577 (72)	total: 501ms	remaining: 871ms
# 73:	learn: 0.2430054	test: 0.6945452	best: 0.6945452 (73)	total: 507ms	remaining: 863ms
# 74:	learn: 0.2422250	test: 0.6942132	best: 0.6942132 (74)	total: 513ms	remaining: 855ms
# 75:	learn: 0.2414809	test: 0.6942007	best: 0.6942007 (75)	total: 520ms	remaining: 848ms
# 76:	learn: 0.2406799	test: 0.6928792	best: 0.6928792 (76)	total: 526ms	remaining: 840ms
# 77:	learn: 0.2401307	test: 0.6916285	best: 0.6916285 (77)	total: 532ms	remaining: 832ms
# 78:	learn: 0.2396199	test: 0.6904822	best: 0.6904822 (78)	total: 538ms	remaining: 825ms
# 79:	learn: 0.2390211	test: 0.6909825	best: 0.6904822 (78)	total: 545ms	remaining: 818ms
# 80:	learn: 0.2382924	test: 0.6885264	best: 0.6885264 (80)	total: 551ms	remaining: 810ms
# 81:	learn: 0.2378169	test: 0.6890862	best: 0.6885264 (80)	total: 557ms	remaining: 802ms
# 82:	learn: 0.2370364	test: 0.6889600	best: 0.6885264 (80)	total: 564ms	remaining: 795ms
# 83:	learn: 0.2366459	test: 0.6885886	best: 0.6885264 (80)	total: 570ms	remaining: 787ms
# 84:	learn: 0.2359726	test: 0.6882732	best: 0.6882732 (84)	total: 575ms	remaining: 779ms
# 85:	learn: 0.2354577	test: 0.6881726	best: 0.6881726 (85)	total: 581ms	remaining: 771ms
# 86:	learn: 0.2345369	test: 0.6882583	best: 0.6881726 (85)	total: 587ms	remaining: 763ms
# 87:	learn: 0.2340913	test: 0.6881973	best: 0.6881726 (85)	total: 596ms	remaining: 759ms
# 88:	learn: 0.2335798	test: 0.6879662	best: 0.6879662 (88)	total: 607ms	remaining: 757ms
# 89:	learn: 0.2326526	test: 0.6877578	best: 0.6877578 (89)	total: 614ms	remaining: 750ms
# 90:	learn: 0.2321999	test: 0.6867604	best: 0.6867604 (90)	total: 620ms	remaining: 743ms
# 91:	learn: 0.2314493	test: 0.6866459	best: 0.6866459 (91)	total: 626ms	remaining: 735ms
# 92:	learn: 0.2307263	test: 0.6867085	best: 0.6866459 (91)	total: 633ms	remaining: 728ms
# 93:	learn: 0.2299446	test: 0.6865184	best: 0.6865184 (93)	total: 639ms	remaining: 721ms
# 94:	learn: 0.2294554	test: 0.6855847	best: 0.6855847 (94)	total: 646ms	remaining: 714ms
# 95:	learn: 0.2287120	test: 0.6841820	best: 0.6841820 (95)	total: 652ms	remaining: 706ms
# 96:	learn: 0.2277937	test: 0.6841139	best: 0.6841139 (96)	total: 658ms	remaining: 699ms
# 97:	learn: 0.2270502	test: 0.6840929	best: 0.6840929 (97)	total: 665ms	remaining: 692ms
# 98:	learn: 0.2263598	test: 0.6838467	best: 0.6838467 (98)	total: 671ms	remaining: 684ms
# 99:	learn: 0.2257072	test: 0.6834689	best: 0.6834689 (99)	total: 677ms	remaining: 677ms
# 100:	learn: 0.2250197	test: 0.6834427	best: 0.6834427 (100)	total: 683ms	remaining: 670ms
# 101:	learn: 0.2245551	test: 0.6834585	best: 0.6834427 (100)	total: 690ms	remaining: 663ms
# 102:	learn: 0.2239611	test: 0.6828060	best: 0.6828060 (102)	total: 696ms	remaining: 656ms
# 103:	learn: 0.2229431	test: 0.6843830	best: 0.6828060 (102)	total: 702ms	remaining: 648ms
# 104:	learn: 0.2221756	test: 0.6841697	best: 0.6828060 (102)	total: 708ms	remaining: 641ms
# 105:	learn: 0.2212607	test: 0.6842600	best: 0.6828060 (102)	total: 714ms	remaining: 634ms
# 106:	learn: 0.2204787	test: 0.6841818	best: 0.6828060 (102)	total: 721ms	remaining: 627ms
# 107:	learn: 0.2197712	test: 0.6854340	best: 0.6828060 (102)	total: 728ms	remaining: 620ms
# 108:	learn: 0.2192510	test: 0.6864976	best: 0.6828060 (102)	total: 735ms	remaining: 613ms
# 109:	learn: 0.2185382	test: 0.6863832	best: 0.6828060 (102)	total: 741ms	remaining: 606ms
# 110:	learn: 0.2179790	test: 0.6858093	best: 0.6828060 (102)	total: 748ms	remaining: 599ms
# 111:	learn: 0.2174456	test: 0.6859018	best: 0.6828060 (102)	total: 754ms	remaining: 592ms
# 112:	learn: 0.2170092	test: 0.6861772	best: 0.6828060 (102)	total: 760ms	remaining: 585ms
# 113:	learn: 0.2163481	test: 0.6864400	best: 0.6828060 (102)	total: 767ms	remaining: 578ms
# 114:	learn: 0.2156329	test: 0.6864952	best: 0.6828060 (102)	total: 773ms	remaining: 571ms
# 115:	learn: 0.2146363	test: 0.6868703	best: 0.6828060 (102)	total: 779ms	remaining: 564ms
# 116:	learn: 0.2137947	test: 0.6876501	best: 0.6828060 (102)	total: 785ms	remaining: 557ms
# 117:	learn: 0.2132301	test: 0.6876289	best: 0.6828060 (102)	total: 791ms	remaining: 550ms
# 118:	learn: 0.2125818	test: 0.6873892	best: 0.6828060 (102)	total: 798ms	remaining: 543ms
# 119:	learn: 0.2119332	test: 0.6885469	best: 0.6828060 (102)	total: 804ms	remaining: 536ms
# 120:	learn: 0.2114021	test: 0.6885336	best: 0.6828060 (102)	total: 810ms	remaining: 529ms
# 121:	learn: 0.2107981	test: 0.6886680	best: 0.6828060 (102)	total: 816ms	remaining: 522ms
# 122:	learn: 0.2102458	test: 0.6886471	best: 0.6828060 (102)	total: 822ms	remaining: 515ms
# 123:	learn: 0.2097294	test: 0.6884881	best: 0.6828060 (102)	total: 829ms	remaining: 508ms
# 124:	learn: 0.2090578	test: 0.6884595	best: 0.6828060 (102)	total: 836ms	remaining: 501ms
# 125:	learn: 0.2086044	test: 0.6878148	best: 0.6828060 (102)	total: 842ms	remaining: 494ms
# 126:	learn: 0.2080396	test: 0.6884468	best: 0.6828060 (102)	total: 848ms	remaining: 488ms
# 127:	learn: 0.2074557	test: 0.6881160	best: 0.6828060 (102)	total: 854ms	remaining: 481ms
# 128:	learn: 0.2065912	test: 0.6882638	best: 0.6828060 (102)	total: 861ms	remaining: 474ms
# 129:	learn: 0.2059515	test: 0.6882651	best: 0.6828060 (102)	total: 867ms	remaining: 467ms
# 130:	learn: 0.2054298	test: 0.6883892	best: 0.6828060 (102)	total: 873ms	remaining: 460ms
# 131:	learn: 0.2049892	test: 0.6879892	best: 0.6828060 (102)	total: 880ms	remaining: 453ms
# 132:	learn: 0.2046547	test: 0.6878356	best: 0.6828060 (102)	total: 886ms	remaining: 446ms
# 133:	learn: 0.2040430	test: 0.6863527	best: 0.6828060 (102)	total: 892ms	remaining: 439ms
# 134:	learn: 0.2032600	test: 0.6867635	best: 0.6828060 (102)	total: 898ms	remaining: 433ms
# 135:	learn: 0.2025416	test: 0.6862802	best: 0.6828060 (102)	total: 905ms	remaining: 426ms
# 136:	learn: 0.2017819	test: 0.6857081	best: 0.6828060 (102)	total: 912ms	remaining: 419ms
# 137:	learn: 0.2013973	test: 0.6860624	best: 0.6828060 (102)	total: 919ms	remaining: 413ms
# 138:	learn: 0.2009710	test: 0.6864887	best: 0.6828060 (102)	total: 925ms	remaining: 406ms
# 139:	learn: 0.2005269	test: 0.6863736	best: 0.6828060 (102)	total: 931ms	remaining: 399ms
# 140:	learn: 0.1996801	test: 0.6866042	best: 0.6828060 (102)	total: 937ms	remaining: 392ms
# 141:	learn: 0.1991509	test: 0.6866732	best: 0.6828060 (102)	total: 944ms	remaining: 385ms
# 142:	learn: 0.1986609	test: 0.6864187	best: 0.6828060 (102)	total: 951ms	remaining: 379ms
# 143:	learn: 0.1978721	test: 0.6871713	best: 0.6828060 (102)	total: 959ms	remaining: 373ms
# 144:	learn: 0.1970944	test: 0.6868594	best: 0.6828060 (102)	total: 966ms	remaining: 366ms
# 145:	learn: 0.1962052	test: 0.6870461	best: 0.6828060 (102)	total: 972ms	remaining: 360ms
# 146:	learn: 0.1956721	test: 0.6869426	best: 0.6828060 (102)	total: 978ms	remaining: 353ms
# 147:	learn: 0.1950552	test: 0.6868767	best: 0.6828060 (102)	total: 985ms	remaining: 346ms
# 148:	learn: 0.1946965	test: 0.6869489	best: 0.6828060 (102)	total: 991ms	remaining: 339ms
# 149:	learn: 0.1943028	test: 0.6868845	best: 0.6828060 (102)	total: 997ms	remaining: 332ms
# 150:	learn: 0.1939638	test: 0.6864990	best: 0.6828060 (102)	total: 1s	remaining: 326ms
# 151:	learn: 0.1935062	test: 0.6857885	best: 0.6828060 (102)	total: 1.01s	remaining: 319ms
# 152:	learn: 0.1931819	test: 0.6864209	best: 0.6828060 (102)	total: 1.02s	remaining: 312ms
# 153:	learn: 0.1923934	test: 0.6869030	best: 0.6828060 (102)	total: 1.02s	remaining: 306ms
# 154:	learn: 0.1919946	test: 0.6871375	best: 0.6828060 (102)	total: 1.03s	remaining: 299ms
# 155:	learn: 0.1915325	test: 0.6868535	best: 0.6828060 (102)	total: 1.03s	remaining: 292ms
# 156:	learn: 0.1909982	test: 0.6871608	best: 0.6828060 (102)	total: 1.04s	remaining: 285ms
# 157:	learn: 0.1905621	test: 0.6867788	best: 0.6828060 (102)	total: 1.05s	remaining: 279ms
# 158:	learn: 0.1900705	test: 0.6875010	best: 0.6828060 (102)	total: 1.05s	remaining: 272ms
# 159:	learn: 0.1896505	test: 0.6868981	best: 0.6828060 (102)	total: 1.06s	remaining: 265ms
# 160:	learn: 0.1890635	test: 0.6886608	best: 0.6828060 (102)	total: 1.07s	remaining: 258ms
# 161:	learn: 0.1886015	test: 0.6884743	best: 0.6828060 (102)	total: 1.07s	remaining: 252ms
# 162:	learn: 0.1880963	test: 0.6884350	best: 0.6828060 (102)	total: 1.09s	remaining: 247ms
# 163:	learn: 0.1876276	test: 0.6884171	best: 0.6828060 (102)	total: 1.09s	remaining: 240ms
# 164:	learn: 0.1870708	test: 0.6885832	best: 0.6828060 (102)	total: 1.1s	remaining: 234ms
# 165:	learn: 0.1862215	test: 0.6871027	best: 0.6828060 (102)	total: 1.11s	remaining: 227ms
# 166:	learn: 0.1858619	test: 0.6874710	best: 0.6828060 (102)	total: 1.11s	remaining: 220ms
# 167:	learn: 0.1853350	test: 0.6874393	best: 0.6828060 (102)	total: 1.12s	remaining: 214ms
# 168:	learn: 0.1849259	test: 0.6881657	best: 0.6828060 (102)	total: 1.13s	remaining: 207ms
# 169:	learn: 0.1842287	test: 0.6869904	best: 0.6828060 (102)	total: 1.14s	remaining: 201ms
# 170:	learn: 0.1837922	test: 0.6858799	best: 0.6828060 (102)	total: 1.14s	remaining: 194ms
# 171:	learn: 0.1830235	test: 0.6852269	best: 0.6828060 (102)	total: 1.15s	remaining: 187ms
# 172:	learn: 0.1825431	test: 0.6853804	best: 0.6828060 (102)	total: 1.16s	remaining: 180ms
# 173:	learn: 0.1818451	test: 0.6852738	best: 0.6828060 (102)	total: 1.16s	remaining: 174ms
# 174:	learn: 0.1813628	test: 0.6849941	best: 0.6828060 (102)	total: 1.17s	remaining: 167ms
# 175:	learn: 0.1809388	test: 0.6852481	best: 0.6828060 (102)	total: 1.17s	remaining: 160ms
# 176:	learn: 0.1805404	test: 0.6852538	best: 0.6828060 (102)	total: 1.18s	remaining: 153ms
# 177:	learn: 0.1802394	test: 0.6853387	best: 0.6828060 (102)	total: 1.19s	remaining: 147ms
# 178:	learn: 0.1798817	test: 0.6860263	best: 0.6828060 (102)	total: 1.19s	remaining: 140ms
# 179:	learn: 0.1793609	test: 0.6860540	best: 0.6828060 (102)	total: 1.2s	remaining: 134ms
# 180:	learn: 0.1789672	test: 0.6860903	best: 0.6828060 (102)	total: 1.21s	remaining: 127ms
# 181:	learn: 0.1786190	test: 0.6858873	best: 0.6828060 (102)	total: 1.22s	remaining: 120ms
# 182:	learn: 0.1782586	test: 0.6860991	best: 0.6828060 (102)	total: 1.22s	remaining: 114ms
# 183:	learn: 0.1777583	test: 0.6859103	best: 0.6828060 (102)	total: 1.23s	remaining: 107ms
# 184:	learn: 0.1770352	test: 0.6863663	best: 0.6828060 (102)	total: 1.24s	remaining: 100ms
# 185:	learn: 0.1762956	test: 0.6860384	best: 0.6828060 (102)	total: 1.24s	remaining: 93.5ms
# 186:	learn: 0.1758629	test: 0.6861068	best: 0.6828060 (102)	total: 1.25s	remaining: 86.9ms
# 187:	learn: 0.1754595	test: 0.6861898	best: 0.6828060 (102)	total: 1.25s	remaining: 80.1ms
# 188:	learn: 0.1751042	test: 0.6852343	best: 0.6828060 (102)	total: 1.26s	remaining: 73.4ms
# 189:	learn: 0.1748037	test: 0.6852703	best: 0.6828060 (102)	total: 1.27s	remaining: 66.7ms
# 190:	learn: 0.1745054	test: 0.6854819	best: 0.6828060 (102)	total: 1.27s	remaining: 60ms
# 191:	learn: 0.1741884	test: 0.6853786	best: 0.6828060 (102)	total: 1.28s	remaining: 53.4ms
# 192:	learn: 0.1737934	test: 0.6851654	best: 0.6828060 (102)	total: 1.29s	remaining: 46.7ms
# 193:	learn: 0.1732829	test: 0.6853751	best: 0.6828060 (102)	total: 1.29s	remaining: 40ms
# 194:	learn: 0.1728007	test: 0.6849366	best: 0.6828060 (102)	total: 1.3s	remaining: 33.3ms
# 195:	learn: 0.1722955	test: 0.6857218	best: 0.6828060 (102)	total: 1.31s	remaining: 26.7ms
# 196:	learn: 0.1717908	test: 0.6857291	best: 0.6828060 (102)	total: 1.31s	remaining: 20ms
# 197:	learn: 0.1715577	test: 0.6854790	best: 0.6828060 (102)	total: 1.32s	remaining: 13.3ms
# 198:	learn: 0.1713062	test: 0.6855268	best: 0.6828060 (102)	total: 1.32s	remaining: 6.66ms
# 199:	learn: 0.1708072	test: 0.6855377	best: 0.6828060 (102)	total: 1.33s	remaining: 0us
# bestTest = 0.6828059584
# bestIteration = 102
# Shrink model to first 103 iterations.
#      prediction  actual
# 0     12.184280  12.950
# 1      9.958843   9.988
# 2      7.224935   6.892
# 3      4.049021   4.038
# 4      3.654414   3.981
# ..          ...     ...
# 155   14.491873  14.755
# 156   12.207186  12.999
# 157   10.037747  10.801
# 158    7.230463   7.433
# 159    4.699695   5.518
#
# [160 rows x 2 columns]
# RMSE = 0.4834340937076086, MSE = 0.23370852295889688, MAE = 0.3960165775763881, MAPE = 0.05324948133586334
# 0.4834340937076086

# %%
# %%time
from statsmodels.tsa.arima.model import ARIMA
ar = ARIMA(dataset, order = (3, 1, 0), seasonal_order = (3, 1, 0, 12))
transformer = nn.generate_transformer(
                    look_back = 12,
                    horizon = 1,
                    n_features = 1,
                    num_transformer_blocks = 4,
                    dropout = 0.25, 
                    head_size = 256, 
                    num_heads = 4, 
                    ff_dim = 4,
                    mlp_units=[128],
                    mlp_dropout=0.4)


gru = nn.generate_rnn(
                  look_back = 12,
                  hidden_layers = 1,
                  units = 64,
                  type = "GRU",
                  dropout = 0.0)

cnn = nn.generate_cnn(look_back = 12,
                hidden_layers = 3,
                kernel_size = 2,
                filters = 64,
                dilation_rate = 1,
                dilation_mode = "multiplicative")

ensemble_model1 = Ensemble(models = [ar, cnn, gru, transformer], regressor = 'wmean')
ensemble_model1.fit(dataset, train_size = 0.95, look_back = 12, val_size = 0.2, train_models_size = 0.7, epochs = 20, batch_size = 16, metric = "rmse")
ensemble_model1.eval(get="rmse")
# Out:
# model 0 : <class 'statsmodels.tsa.arima.model.ARIMAResultsWrapper'>, rmse = 0.5003963440169422
#
# 23/23 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# model 1 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.3186140893504168
#
# 23/23 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# model 2 : <class 'keras.engine.sequential.Sequential'>, rmse = 0.33838424588352894
#
# 23/23 [==============================] - 1s 29ms/step
# 6/6 [==============================] - 0s 22ms/step
# 6/6 [==============================] - 0s 21ms/step
# model 3 : <class 'keras.engine.functional.Functional'>, rmse = 0.46480200682307804
#      prediction  actual
# 0     14.796259  14.560
# 1     12.872903  12.950
# 2     10.302655   9.988
# 3      7.168596   6.892
# 4      4.804625   4.038
# ..          ...     ...
# 156   14.732538  14.755
# 157   12.960722  12.999
# 158   10.374619  10.801
# 159    7.448648   7.433
# 160    5.143746   5.518
#
# [161 rows x 2 columns]
# RMSE = 0.36002770485737123, MSE = 0.12961994826486642, MAE = 0.27449661051436586, MAPE = 0.043541910903192434
# CPU times: total: 6min 6s
# Wall time: 2min 12s
# 0.36002770485737123

# %% [markdown]
# Также построим CNN LSTM модель.

# %%
# %%time
seq = nn.make_seq_model(dataset, 
            layers = ["cnn", "lstm"], 
            look_back = 12, 
            units = 64,
            filters = 64,
            horizon = 1, 
            dropout = 0.0, 
            n_features = 1, 
            kernel_size = 2, 
            dilation_rate = 1, 
            dilation_mode = "multiplicative",
            optimizer = "Adam",
            loss = "mae",
            train_size = 0.95, 
            plot = True,
            batch_size = 16,
            epochs = 30,
            maxPlot = 100, 
            fig_size = (15, 5))
# Out:
# 5/5 [==============================] - 0s 2ms/step
#      prediction  actual
# 0     12.352341  12.911
# 1     10.314637  10.424
# 2      7.899449   6.727
# 3      5.441472   5.133
# 4      4.631914   3.525
# ..          ...     ...
# 143   13.605193  14.755
# 144   12.348840  12.999
# 145   10.396079  10.801
# 146    8.044506   7.433
# 147    5.837587   5.518
#
# [148 rows x 2 columns]
# RMSE = 0.9241304044709721, MSE = 0.8540170044676824, MAE = 0.8062804086832712, MAPE = 0.10622524058947691
# CPU times: total: 43.3 s
# Wall time: 19.8 s

# %% [markdown]
# Построим предсказания на следующие n значений используя некоторые из моделей.

# %%
# %%time
ensemble_model.forecast(dataset, 12, fig_size = (5,5))
# Out:
# CPU times: total: 7.95 s
# Wall time: 7.44 s
#             predictions
# 2016-01-01     3.709064
# 2016-02-01     4.702684
# 2016-03-01     6.268749
# 2016-04-01     9.489960
# 2016-05-01    12.933349
# 2016-06-01    14.153758
# 2016-07-01    14.215729
# 2016-08-01    14.195324
# 2016-09-01    13.462396
# 2016-10-01     9.881792
# 2016-11-01     6.380461
# 2016-12-01     6.423404

# %%
# %%time
# from statsmodels.tsa.arima.model import ARIMA
# ar = ARIMA(dataset, order = (2, 0, 1), seasonal_order = (2, 0, 1, 23))
utils.model_forecast(ar, dataset, 12, fig_size = (5,5))
# Out:
# CPU times: total: 5.67 s
# Wall time: 5.22 s
#             predictions
# 2016-01-01     4.220717
# 2016-02-01     4.630549
# 2016-03-01     6.990239
# 2016-04-01    10.085731
# 2016-05-01    13.067435
# 2016-06-01    15.104198
# 2016-07-01    15.638341
# 2016-08-01    15.412140
# 2016-09-01    13.698222
# 2016-10-01    11.120328
# 2016-11-01     7.812919
# 2016-12-01     5.469307
